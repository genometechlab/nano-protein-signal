# %% [markdown]
# ## Imports and Setup

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import pandas as pd
import sys
from pathlib import Path

# Go up two levels: notebooks/ -> profile_analyzer/ -> hmm/
# The hmm/ directory contains the profile_analyzer module
project_root = Path.cwd().parent.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from profile_analyzer import HMMClassificationAnalyzer, HMMVisualizationPlotter

# %% [markdown]
# # HMM Classification Analysis: C vs D
#
# **Objective:** Analyze misclassification patterns between amino acids C (Cysteine) and D (Aspartic acid) to understand why the HMM fails on certain traces.
#
# **Date:** December 11, 2024
#
# **Approach:**
# 1. Load 20-way classification results and identify misclassifications
# 2. Compare with circle test (baseline) to find systematic failures
# 3. Analyze skip patterns in critical segment regions (10-25)
# 4. Generate KDE visualizations to understand distribution differences

# %% [markdown]
# ## Data Loading
# Loading all required data sources:
# - 20-way classification results
# - Circle test results (amino acids vs their own profiles)
# - Segment data (cleaned signal segments)
# - Profile data (HMM emission profiles)

# %% [markdown]
# ### Config

# %%
RESULTS_FILE = '/projects/Genometechlab/andrew/protein/nano-protein-signal/hmm/vrhmm/results/original_20way_classification/results_20way_segment_20251211_105304.json'
C_CIRCLE_TEST_FILE = '/projects/Genometechlab/andrew/protein/nano-protein-signal/hmm/vrhmm/results/original_C_circle_test/results_20way_segment_20251211_115308.json'
D_CIRCLE_TEST_FILE = '/projects/Genometechlab/andrew/protein/nano-protein-signal/hmm/vrhmm/results/original_D_circle_test/results_20way_segment_20251211_115116.json'

CIRCLE_TEST_FILE = C_CIRCLE_TEST_FILE
SEGMENT_PICKLE = '/projects/Genometechlab/andrew/protein/nano-protein-signal/hmm/vrhmm/data/denoise_segment_dynp_parallel_34_BkP_full_pastor_norm_features_clean_1751_4570_min_size_30_length_iqr_25_75_pretty_25_per_aa.pkl'
PROFILE_CSV = '/projects/Genometechlab/andrew/protein/nano-protein-signal/hmm/vrhmm/results/original_20way_classification/hmm_profiles_20251211_105304.csv'

TARGET_AAS = ['C']
SEGMENT_RANGE = (5, 30)

# %% [markdown]
# ### Initialize Analyzer and Load Data

# %%
analyzer = HMMClassificationAnalyzer(
    results_file=RESULTS_FILE,
    target_aas=TARGET_AAS,
    verbose=True
)

(analyzer
 .load_and_clean()
 .filter_keys()
 .find_misclassified()
 .load_circle_test(CIRCLE_TEST_FILE)
 .match_circle_to_misclassified()
 .load_segment_data(SEGMENT_PICKLE)
 .zscore_normalize_segments()
 .load_profiles(PROFILE_CSV, load_all_aas=True))
# Out:
# Initialized analyzer for amino acids: ['C']
#
# Loading results from /projects/Genometechlab/andrew/protein/nano-protein-signal/hmm/vrhmm/results/original_20way_classification/results_20way_segment_20251211_105304.json
# Filtered to 25 traces for target amino acids
# Filtered 25 traces to keep keys: ['full_path', 'amino_acid', 'predicted_category', 'log_probability']
#
# Finding misclassified traces...
# Found 22 misclassified traces
#
# Misclassification distribution:
#   C -> A: 1 traces
#   C -> D: 1 traces
#   C -> E: 3 traces
#   C -> F: 2 traces
#   C -> G: 1 traces
#   C -> H: 1 traces
#   C -> I: 1 traces
#   C -> K: 1 traces
#   C -> L: 1 traces
#   C -> M: 1 traces
#   C -> N: 1 traces
#   C -> Q: 1 traces
#   C -> R: 4 traces
#   C -> S: 1 traces
#   C -> V: 1 traces
#   C -> W: 1 traces
#
# Loading circle test results from /projects/Genometechlab/andrew/protein/nano-protein-signal/hmm/vrhmm/results/original_C_circle_test/results_20way_segment_20251211_115308.json
# Filtered to 25 circle test traces
#
# Matching misclassified traces with circle test data...
# Successfully matched 22 traces
#
# Example log probability comparison:
#   Trace: 20221121_run01_a_64.0_5765_C
#   Circle test: -19.49
#   Misclassified: -19.26
#
# Loading segment data from /projects/Genometechlab/andrew/protein/nano-protein-signal/hmm/vrhmm/data/denoise_segment_dynp_parallel_34_BkP_full_pastor_norm_features_clean_1751_4570_min_size_30_length_iqr_25_75_pretty_25_per_aa.pkl
# Loaded 500 segment records
# Created mapping for 500 traces
# Sample trace IDs: ['20220826_run03_a_433.0_1781_A', '20220826_run03_a_53.0_1431_A', '20221220_run04_a_48.0_8249_A']
# 22/22 misclassified traces have segment data
#
# Z-score normalizing segment data...
# Z-score normalized 500 traces
#
# Loading profiles from /projects/Genometechlab/andrew/protein/nano-protein-signal/hmm/vrhmm/results/original_20way_classification/hmm_profiles_20251211_105304.csv
# Loaded 35 profile rows
# Columns: ['amino_acid', 'state', 'mean', 'std', 'var']
# Amino acids in profiles: ['C']

# %% [markdown]
# ## Initial Exploration
#
# Let's look at the confusion patterns to understand what we're dealing with.

# %% [markdown]
# ### Examing Confusion Pairs

# %%
# Cell 4: Examine confusion patterns
confusion_pairs = analyzer.get_confusion_pairs()

print("Misclassification summary:")
for (true_aa, pred_aa), traces in confusion_pairs.items():
    print(f"  {true_aa} misclassified as {pred_aa}: {len(traces)} traces")
# Out:
# Misclassification summary:
#   C misclassified as M: 1 traces
#   C misclassified as K: 1 traces
#   C misclassified as R: 4 traces
#   C misclassified as F: 2 traces
#   C misclassified as S: 1 traces
#   C misclassified as A: 1 traces
#   C misclassified as Q: 1 traces
#   C misclassified as N: 1 traces
#   C misclassified as H: 1 traces
#   C misclassified as I: 1 traces
#   C misclassified as W: 1 traces
#   C misclassified as V: 1 traces
#   C misclassified as E: 3 traces
#   C misclassified as D: 1 traces
#   C misclassified as G: 1 traces
#   C misclassified as L: 1 traces

# %%
analyzer.debug_emitting_state_counts()
# Out:
# Debugging emitting state counts in paths...
#
# Trace ID                                 | Segs | Circle (M+I) | Misclass (M+I)
# ------------------------------------------------------------------------------------------
# 20221121_run01_a_64.0_5765_C             |   35 | 35+ 0=35 | 35+ 0=35
# 20220826_run02_a_161.0_1185_C            |   35 | 35+ 0=35 | 35+ 0=35
# 20221220_run01_a_253.0_7849_C            |   35 | 35+ 0=35 | 35+ 0=35
# 20221122_run03_a_310.0_6983_C            |   35 | 35+ 0=35 | 35+ 0=35
# 20221220_run01_a_50.0_7583_C             |   35 | 35+ 0=35 | 35+ 0=35
# 20221109_run04_a_221.0_5021_C            |   35 | 35+ 0=35 | 35+ 0=35
# 20221109_run04_a_465.0_5049_C            |   35 | 34+ 1=35 | 35+ 0=35
# 20221122_run03_a_61.0_6885_C             |   35 | 35+ 0=35 | 35+ 0=35
# 20221221_run02_a_127.0_9055_C            |   35 | 35+ 0=35 | 34+ 1=35
# 20221109_run04_a_153.0_5007_C            |   35 | 35+ 0=35 | 35+ 0=35
# 20220826_run02_a_491.0_1367_C            |   35 | 35+ 0=35 | 34+ 1=35
# 20221220_run01_a_288.0_7905_C            |   35 | 35+ 0=35 | 35+ 0=35
# 20221221_run02_a_180.0_9125_C            |   35 | 35+ 0=35 | 35+ 0=35
# 20221220_run01_a_258.0_7863_C            |   35 | 35+ 0=35 | 35+ 0=35
# 20221121_run01_a_348.0_5821_C            |   35 | 35+ 0=35 | 35+ 0=35
# 20221122_run03_a_484.0_7025_C            |   35 | 35+ 0=35 | 35+ 0=35
# 20220826_run02_a_322.0_1311_C            |   35 | 34+ 1=35 | 35+ 0=35
# 20221121_run01_a_122.1_5695_C            |   35 | 35+ 0=35 | 35+ 0=35
# 20221121_run01_a_46.0_5723_C             |   35 | 35+ 0=35 | 35+ 0=35
# 20221221_run02_a_178.0_9139_C            |   35 | 35+ 0=35 | 35+ 0=35
#
# Summary Statistics:
# Segment counts: min=35, max=35, unique values={35}
# Circle test emitting states: min=35, max=35, unique values={35}
# Misclass emitting states: min=35, max=35, unique values={35}
#
# All traces have matching emitting state counts!

# %% [markdown]
# ## Visualization Setup
#
# Initialize the plotter with seaborn styling for better-looking plots.

# %% [markdown]
# ## Skip Pattern Analysis
#
# Comparing which states in the critical region (10-25) are skipped in:
# - Circle test (baseline - should be minimal skipping)
# - Misclassified runs (problematic cases)
#
# This will help identify if the HMM is systematically avoiding certain states.

# %% [markdown]
# ### Observations from skip patterns:
#
# Need to double check that the segment indices are correct, because there are a few dots right on the mean of a given profile, and I'm not sure the analysis is correct for these.
#
# - Which states are skipped more frequently?
# - Is there a difference between circle test and misclassified?
# - Any patterns or clusters?

# %% [markdown]
# ### Detailed Skip Analysis

# %%
skip_analysis_full = analyzer.analyze_skip_patterns((0, 34))

traces_with_skips_full = {
    trace_id: analysis 
    for trace_id, analysis in skip_analysis_full.items() 
    if analysis['circle_skipped']
}

print(f"\nFull range (0-34) analysis:")
print(f"Found {len(traces_with_skips_full)} traces with skipped states")

from collections import Counter
all_skipped_states = []
for analysis in traces_with_skips_full.values():
    all_skipped_states.extend(analysis['circle_skipped'])

skip_distribution = Counter(all_skipped_states)
print(f"\nSkip distribution across all states:")
for state, count in sorted(skip_distribution.items()):
    print(f"  State {state}: skipped {count} times")
# Out:
# Analyzing skip patterns for segment range (0, 34)
# Completed skip pattern analysis for 22 traces
# Total states skipped in circle tests: 31
# Total states skipped in misclassified: 21
#
# Full range (0-34) analysis:
# Found 11 traces with skipped states
#
# Skip distribution across all states:
#   State 3: skipped 4 times
#   State 4: skipped 3 times
#   State 11: skipped 2 times
#   State 12: skipped 2 times
#   State 13: skipped 4 times
#   State 14: skipped 2 times
#   State 15: skipped 2 times
#   State 21: skipped 2 times
#   State 29: skipped 1 times
#   State 30: skipped 2 times
#   State 31: skipped 4 times
#   State 32: skipped 1 times
#   State 33: skipped 1 times
#   State 34: skipped 1 times

# %%
# Cell 6: Analyze specific segment range
skip_analysis = analyzer.analyze_skip_patterns(SEGMENT_RANGE)

traces_with_skips = {
    trace_id: analysis 
    for trace_id, analysis in skip_analysis.items() 
    if analysis['circle_skipped'] or analysis['misclass_skipped']
}

print(f"\nFound {len(traces_with_skips)} traces with skipped states in range {SEGMENT_RANGE}")
print(f"(out of {len(skip_analysis)} total traces)\n")

if traces_with_skips:
    print("Traces WITH skip patterns:\n")
    for trace_id, analysis in list(traces_with_skips.items())[:10]:
        print(f"{trace_id}:")
        print(f"  True: {analysis['true_aa']} -> Predicted: {analysis['predicted_aa']}")
        print(f"  Circle skipped: {analysis['circle_skipped']}")
        print(f"  Misclass skipped: {analysis['misclass_skipped']}")
        print(f"  Both skipped: {analysis['both_skipped']}\n")
# Out:
# Analyzing skip patterns for segment range (5, 30)
# Completed skip pattern analysis for 22 traces
# Total states skipped in circle tests: 17
# Total states skipped in misclassified: 3
#
# Found 8 traces with skipped states in range (5, 30)
# (out of 22 total traces)
#
# Traces WITH skip patterns:
#
# 20221109_run04_a_221.0_5021_C:
#   True: C -> Predicted: A
#   Circle skipped: [30]
#   Misclass skipped: []
#   Both skipped: []
#
# 20221109_run04_a_465.0_5049_C:
#   True: C -> Predicted: Q
#   Circle skipped: [13]
#   Misclass skipped: []
#   Both skipped: []
#
# 20221221_run02_a_127.0_9055_C:
#   True: C -> Predicted: H
#   Circle skipped: [21]
#   Misclass skipped: []
#   Both skipped: []
#
# 20221121_run01_a_348.0_5821_C:
#   True: C -> Predicted: E
#   Circle skipped: []
#   Misclass skipped: [30]
#   Both skipped: []
#
# 20220826_run02_a_322.0_1311_C:
#   True: C -> Predicted: D
#   Circle skipped: [11, 12, 13]
#   Misclass skipped: []
#   Both skipped: []
#
# 20221121_run01_a_46.0_5723_C:
#   True: C -> Predicted: L
#   Circle skipped: [21, 29, 30]
#   Misclass skipped: [30]
#   Both skipped: [30]
#
# 20221121_run01_a_221.0_5779_C:
#   True: C -> Predicted: E
#   Circle skipped: [13, 14, 15]
#   Misclass skipped: []
#   Both skipped: []
#
# 20221122_run03_a_396.0_6997_C:
#   True: C -> Predicted: E
#   Circle skipped: [11, 12, 13, 14, 15]
#   Misclass skipped: [5]
#   Both skipped: []

# %%
# Cell 7: Debug specific trace paths
if traces_with_skips_full:
    trace_id = list(traces_with_skips_full.keys())[0]
    skipped_state = traces_with_skips_full[trace_id]['circle_skipped'][0]
    
    print(f"Debugging trace: {trace_id}")
    print(f"Looking at skipped state: {skipped_state}\n")
    
    analyzer.debug_skip_state_context(trace_id, skipped_state, context=2)
# Out:
# Debugging trace: 20221220_run01_a_50.0_7583_C
# Looking at skipped state: 3
#
# Debug for 20221220_run01_a_50.0_7583_C at Match state 3
# Target state: Match_3
#
# CIRCLE TEST PATH (where state was potentially skipped):
# ------------------------------------------------------------
#   Match_3 NOT IN PATH (was skipped)
#
#   Last match before skip:
#      Path index 0: Match_0
#      Path index 1: Match_1
#  >>> Path index 2: Match_2
#      Path index 3: Skip_2
#      Path index 4: Skip_3
#
#   First match after skip:
#      Path index 4: Skip_3
#      Path index 5: Skip_4
#  >>> Path index 6: Match_5
#      Path index 7: Match_6
#      Path index 8: Match_7
#
# MISCLASSIFIED PATH (where state was potentially matched):
# ------------------------------------------------------------
#      Path index 1: Match_1
#      Path index 2: Match_2
#  >>> Path index 3: Match_3
#      Path index 4: Match_4
#      Path index 5: Match_5

# %%
# Cell 8: Validate segment coverage
state_coverage = analyzer.validate_segment_coverage(segment_range=(0, 34))
# Out:
# Validating segment coverage for range (0, 34)
#
# Analyzing skip patterns for segment range (0, 34)
# Completed skip pattern analysis for 22 traces
# Total states skipped in circle tests: 31
# Total states skipped in misclassified: 21
#
# Expected count per state: 22 traces
#
# State coverage:
# ✓ State 0: 22 matched + 0 skipped = 22 total
# ✓ State 1: 22 matched + 0 skipped = 22 total
# ✓ State 2: 22 matched + 0 skipped = 22 total
# ✓ State 3: 18 matched + 4 skipped = 22 total
# ✓ State 4: 19 matched + 3 skipped = 22 total
# ✓ State 5: 22 matched + 0 skipped = 22 total
# ✓ State 6: 22 matched + 0 skipped = 22 total
# ✓ State 7: 22 matched + 0 skipped = 22 total
# ✓ State 8: 22 matched + 0 skipped = 22 total
# ✓ State 9: 22 matched + 0 skipped = 22 total
# ✓ State 10: 22 matched + 0 skipped = 22 total
# ✓ State 11: 20 matched + 2 skipped = 22 total
# ✓ State 12: 20 matched + 2 skipped = 22 total
# ✓ State 13: 18 matched + 4 skipped = 22 total
# ✓ State 14: 20 matched + 2 skipped = 22 total
# ✓ State 15: 20 matched + 2 skipped = 22 total
# ✓ State 16: 22 matched + 0 skipped = 22 total
# ✓ State 17: 22 matched + 0 skipped = 22 total
# ✓ State 18: 22 matched + 0 skipped = 22 total
# ✓ State 19: 22 matched + 0 skipped = 22 total
# ✓ State 20: 22 matched + 0 skipped = 22 total
# ✓ State 21: 20 matched + 2 skipped = 22 total
# ✓ State 22: 22 matched + 0 skipped = 22 total
# ✓ State 23: 22 matched + 0 skipped = 22 total
# ✓ State 24: 22 matched + 0 skipped = 22 total
# ✓ State 25: 22 matched + 0 skipped = 22 total
# ✓ State 26: 22 matched + 0 skipped = 22 total
# ✓ State 27: 22 matched + 0 skipped = 22 total
# ✓ State 28: 22 matched + 0 skipped = 22 total
# ✓ State 29: 21 matched + 1 skipped = 22 total
# ✓ State 30: 20 matched + 2 skipped = 22 total
# ✓ State 31: 18 matched + 4 skipped = 22 total
# ✓ State 32: 21 matched + 1 skipped = 22 total
# ✓ State 33: 21 matched + 1 skipped = 22 total
# ✓ State 34: 21 matched + 1 skipped = 22 total
#
# All states have correct coverage: 22 traces each

# %%
# Cell 9: Initialize plotter and create figures directory
from pathlib import Path
Path('figures').mkdir(exist_ok=True)

plotter = HMMVisualizationPlotter(analyzer, style='white', context='notebook')
# Out:
# Initialized visualization plotter

# %%
# Cell 10: Create profile skip analysis plot
fig = plotter.plot_profile_skip_analysis(
    segment_range=(0, 34), 
    figsize=(16, 8),
    use_normalized=True
)
plt.savefig('figures/c_profile_skip_analysis.pdf', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Creating profile skip analysis plot
#
# Analyzing skip patterns for segment range (0, 34)
# Completed skip pattern analysis for 22 traces
# Total states skipped in circle tests: 31
# Total states skipped in misclassified: 21
# Profile skip analysis plot created

# %%
# Cell 11: Find and plot skipped states within profile
within_profile = analyzer.find_skips_within_profile(segment_range=(0, 34))

if within_profile:
    print(f"\nFound {len(within_profile)} skipped states within profile std:")
    for skip in within_profile[:10]:
        print(f"  {skip['trace_id']}: State {skip['state_pos']}, "
              f"deviation = {skip['deviation']:.2f}σ")
    
    plotter.plot_individual_skip_details(within_profile, max_plots=10)
else:
    print("No skipped states found within profile standard deviation")
# Out:
# Finding skipped states within profile standard deviation...
#
# Analyzing skip patterns for segment range (0, 34)
# Completed skip pattern analysis for 22 traces
# Total states skipped in circle tests: 31
# Total states skipped in misclassified: 21
# Found 9 skipped states within profile std
#
# Found 9 skipped states within profile std:
#   20221109_run04_a_221.0_5021_C: State 30, deviation = 0.78σ
#   20221109_run04_a_221.0_5021_C: State 31, deviation = 0.15σ
#   20220826_run02_a_322.0_1311_C: State 11, deviation = 0.25σ
#   20220826_run02_a_322.0_1311_C: State 12, deviation = 0.51σ
#   20221121_run01_a_221.0_5779_C: State 14, deviation = 0.65σ
#   20221121_run01_a_221.0_5779_C: State 15, deviation = 0.10σ
#   20221122_run03_a_396.0_6997_C: State 3, deviation = 0.02σ
#   20221122_run03_a_396.0_6997_C: State 11, deviation = 0.78σ
#   20221122_run03_a_396.0_6997_C: State 12, deviation = 0.91σ
#
# Creating 9 detailed skip plots...
#   Saved: figures/skip_details/skip_detail_20221109_run04_a_221.0_5021_C_state30.pdf
#   Saved: figures/skip_details/skip_detail_20221109_run04_a_221.0_5021_C_state31.pdf
#   Saved: figures/skip_details/skip_detail_20220826_run02_a_322.0_1311_C_state11.pdf
#   Saved: figures/skip_details/skip_detail_20220826_run02_a_322.0_1311_C_state12.pdf
#   Saved: figures/skip_details/skip_detail_20221121_run01_a_221.0_5779_C_state14.pdf
#   Saved: figures/skip_details/skip_detail_20221121_run01_a_221.0_5779_C_state15.pdf
#   Saved: figures/skip_details/skip_detail_20221122_run03_a_396.0_6997_C_state3.pdf
#   Saved: figures/skip_details/skip_detail_20221122_run03_a_396.0_6997_C_state11.pdf
#   Saved: figures/skip_details/skip_detail_20221122_run03_a_396.0_6997_C_state12.pdf
#
# Completed 9 detail plots

# %% [markdown]
# ## KDE Distribution Analysis
#
# For traces where states were skipped in the circle test, we'll compare:
# 1. The actual segment signal distributions
# 2. The profile for the correct amino acid
# 3. The profile for the incorrectly predicted amino acid
#
# This helps us understand why the HMM might prefer the wrong amino acid.

# %%
# Cell 12: Prepare and plot KDE comparisons
kde_comparison_data = analyzer.prepare_kde_comparison_data(within_profile)

if kde_comparison_data:
    plotter.plot_kde_comparisons(kde_comparison_data, max_plots=10)
else:
    print("No KDE comparison data available")
# Out:
# Preparing KDE comparison data...
# Prepared KDE data for 0 skipped states
# No KDE comparison data available

# %%
# Cell 10: Plot KDE pileups
fig_kde = plotter.plot_kde_pileup(kde_data, max_cols=4, figsize_per_subplot=(4, 3))
plt.savefig('figures/c_d_kde_pileup.pdf', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Cell 10: Plot KDE pileups
# ----> 2 fig_kde = plotter.plot_kde_pileup(kde_data, max_cols=4, figsize_per_subplot=(4, 3))
#       3 plt.savefig('figures/c_d_kde_pileup.pdf', dpi=300, bbox_inches='tight')
#       4 plt.show()
#
# AttributeError: 'HMMVisualizationPlotter' object has no attribute 'plot_kde_pileup'

# %% [markdown]
# ### KDE Analysis Observations:
#
# [Add your observations here]
# - Do the segment distributions align better with true or predicted profiles?
# - Are there systematic biases?
# - Which traces show the most disagreement?

# %% [markdown]
# ### AA-pair specific focus

# %%
# Cell 11: Focus on specific confusion pair - C misclassified as K
c_to_k = [d for d in kde_data if d['true_aa'] == 'C' and d['predicted_aa'] == 'K']

if c_to_k:
    print(f"Found {len(c_to_k)} C->K misclassifications with skipped states")
    
    fig_c_k = plotter.plot_kde_pileup(c_to_k, max_cols=3, figsize_per_subplot=(5, 3))
    plt.suptitle('C misclassified as K: Detailed KDE Analysis', fontsize=16, y=1.02)
    plt.savefig('figures/c_to_k_kde_detail.png', dpi=300, bbox_inches='tight')
    plt.show()

# %% [markdown]
# ## Log Probability Analysis
#
# Compare the log probabilities between circle test and misclassified runs to see how confident the model is in each case.

# %%
# Cell 12: Log probability comparison
fig_logprob = plotter.plot_log_probability_comparison(figsize=(12, 5))
plt.savefig('figures/c_d_logprob_comparison.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Cell 13: Statistical summary of log probabilities
import numpy as np

circle_probs = [d['circle_test']['log_probability'] 
                for d in analyzer.matched_data.values()]
misclass_probs = [d['misclassified']['log_probability'] 
                  for d in analyzer.matched_data.values()]

print("Log Probability Statistics:")
print(f"\nCircle Test:")
print(f"  Mean: {np.mean(circle_probs):.2f}")
print(f"  Std: {np.std(circle_probs):.2f}")
print(f"  Range: [{np.min(circle_probs):.2f}, {np.max(circle_probs):.2f}]")

print(f"\nMisclassified:")
print(f"  Mean: {np.mean(misclass_probs):.2f}")
print(f"  Std: {np.std(misclass_probs):.2f}")
print(f"  Range: [{np.min(misclass_probs):.2f}, {np.max(misclass_probs):.2f}]")

print(f"\nMean difference: {np.mean(misclass_probs) - np.mean(circle_probs):.2f}")

# %% [markdown]
# ## Deep Dive: Worst Performers
#
# Let's examine the traces with the largest log probability drops (circle test to misclassified).

# %%
# Cell 15: Find worst performers
logprob_drops = []
for trace_id, data in analyzer.matched_data.items():
    circle_lp = data['circle_test']['log_probability']
    misclass_lp = data['misclassified']['log_probability']
    drop = circle_lp - misclass_lp
    
    logprob_drops.append({
        'trace_id': trace_id,
        'true_aa': trace_id.split('_')[-1],
        'pred_aa': data['misclassified']['predicted_category'],
        'circle_logprob': circle_lp,
        'misclass_logprob': misclass_lp,
        'drop': drop
    })

df_drops = pd.DataFrame(logprob_drops)
df_drops = df_drops.sort_values('drop', ascending=False)

print("Top 10 worst performers (largest log probability drops):")
print(df_drops.head(10).to_string(index=False))

# %%
# Cell 16: Investigate specific trace
worst_trace_id = df_drops.iloc[0]['trace_id']
worst_analysis = skip_analysis[worst_trace_id]

print(f"Detailed analysis of worst performer: {worst_trace_id}")
print(f"True AA: {worst_analysis['true_aa']}")
print(f"Predicted AA: {worst_analysis['predicted_aa']}")
print(f"\nCircle test path length: {len(worst_analysis['circle_path'])}")
print(f"Misclassified path length: {len(worst_analysis['misclass_path'])}")
print(f"\nStates skipped in circle test: {worst_analysis['circle_skipped']}")
print(f"States skipped in misclassified: {worst_analysis['misclass_skipped']}")
print(f"States skipped in both: {worst_analysis['both_skipped']}")
